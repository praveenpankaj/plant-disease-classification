# %%
pip install pyinaturalist
# Out:
# Collecting pyinaturalist
#   Downloading pyinaturalist-0.19.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from pyinaturalist) (24.2.0)
# Requirement already satisfied: keyring>=22.3 in /usr/lib/python3/dist-packages (from pyinaturalist) (23.5.0)
# Requirement already satisfied: markdown-it-py>=3.0 in /usr/local/lib/python3.10/dist-packages (from pyinaturalist) (3.0.0)
# Requirement already satisfied: platformdirs>=2.6 in /usr/local/lib/python3.10/dist-packages (from pyinaturalist) (4.3.6)
# Requirement already satisfied: python-dateutil>=2.0 in /usr/local/lib/python3.10/dist-packages (from pyinaturalist) (2.8.2)
# Collecting python-forge>=18.6 (from pyinaturalist)
#   Downloading python_forge-18.6.0-py35-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.10/dist-packages (from pyinaturalist) (2.32.3)
# Collecting requests-cache>=1.1 (from pyinaturalist)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting requests-ratelimiter>=0.3.2 (from pyinaturalist)
#   Downloading requests_ratelimiter-0.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: rich>=10.9 in /usr/local/lib/python3.10/dist-packages (from pyinaturalist) (13.8.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=3.0->pyinaturalist) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.0->pyinaturalist) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->pyinaturalist) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->pyinaturalist) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->pyinaturalist) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->pyinaturalist) (2024.8.30)
# Collecting cattrs>=22.2 (from requests-cache>=1.1->pyinaturalist)
#   Downloading cattrs-24.1.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting url-normalize>=1.4 (from requests-cache>=1.1->pyinaturalist)
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl.metadata (3.1 kB)
# Collecting pyrate-limiter<3.0 (from requests-ratelimiter>=0.3.2->pyinaturalist)
#   Downloading pyrate_limiter-2.10.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.9->pyinaturalist) (2.18.0)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache>=1.1->pyinaturalist) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache>=1.1->pyinaturalist) (4.12.2)
# Downloading pyinaturalist-0.19.0-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 2.5 MB/s eta 0:00:00
# Downloading python_forge-18.6.0-py35-none-any.whl (31 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.0 MB/s eta 0:00:00
# Downloading requests_ratelimiter-0.7.0-py3-none-any.whl (9.3 kB)
# Downloading cattrs-24.1.2-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.8 MB/s eta 0:00:00
# Downloading pyrate_limiter-2.10.0-py3-none-any.whl (16 kB)
# Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Installing collected packages: python-forge, url-normalize, pyrate-limiter, cattrs, requests-ratelimiter, requests-cache, pyinaturalist
# Successfully installed cattrs-24.1.2 pyinaturalist-0.19.0 pyrate-limiter-2.10.0 python-forge-18.6.0 requests-cache-1.2.1 requests-ratelimiter-0.7.0 url-normalize-1.4.3

# %%
from pyinaturalist import *

# %%
counts = get_observation_species_counts(user_id='my_username', quality_grade='research')
pprint(counts)
Common name             Count
━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
47934   species   🐛 Libellula luctuosa         Widow Skimmer           7
48627   species   🌻 Echinacea purpurea         Purple Coneflower       6
504060  species   🍄 Pleurotus citrinopileatus  Golden Oyster Mushroom  6
...
# Out:
#   File "<ipython-input-3-f4a150a26c6e>", line 4
#     ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     ^
# SyntaxError: invalid character '━' (U+2501)
